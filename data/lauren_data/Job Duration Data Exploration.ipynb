# %%
import pandas
import numpy
import plotly.plotly as py
from plotly.graph_objs import *
import plotly.tools as tls
tls.set_credentials_file(
        username="", 
        api_key="")
import numpy as np
import matplotlib.pyplot as plt

# %pylab
# Out:
# Using matplotlib backend: MacOSX
# Populating the interactive namespace from numpy and matplotlib
# WARNING: pylab import has clobbered these variables: ['Annotation', 'Figure']
# `%matplotlib` prevents importing * from pylab and numpy

# %%
jobs = pandas.read_csv('../data.csv')
jobs = jobs[jobs.Duration_yr >= 0]
jobs = jobs[jobs.EndDate != 'Present']

# %%
jobs.head()
# Out:
#                      JobTitle               Company       StartDate  \
# 3             Visual Designer      Good World Media       July 2011
# 4        Visual Design Intern                  CIBO    January 2013
# 5   Interactive Design Intern             remind101       July 2012
# 6             Junior Designer  The Shotwell Company  September 2011
# 7  Marketing and Print Intern              Club One  September 2011
#
#           EndDate          Duration                Location  Duration_yr  \
# 3   November 2013  2 years 5 months                New York     2.416667
# 4        May 2013          5 months  San Francisco Bay Area     0.416667
# 5  September 2012          3 months  San Francisco Bay Area     0.250000
# 6       July 2012         11 months  San Francisco Bay Area     0.916667
# 7   December 2011          4 months  San Francisco Bay Area     0.333333
#
#     JobType LocationType
# 3  Designer           NY
# 4    Intern           CA
# 5    Intern           CA
# 6  Designer           CA
# 7    Intern           CA

# %%
jobGroups = jobs.groupby('JobType')
summaryTable = jobGroups['Duration_yr'].agg([np.sum, np.mean, np.std, np.median, len]).sort('median', ascending=False)
print summaryTable
# Out:
#                      sum      mean       std    median  len
# JobType
# Founder        30.250000  4.321429  2.349856  4.000000    7
# Consultant     20.500000  2.050000  1.450415  2.125000   10
# Engineer       54.750000  2.737500  3.556178  2.083333   20
# PM              4.833333  1.611111  0.822147  2.000000    3
# Scientist       9.250000  2.312500  1.167410  1.916667    4
# Research      118.416667  2.041667  1.928311  1.416667   58
# Other         180.083333  1.875868  1.705855  1.375000   96
# Software Eng    7.250000  2.416667  2.994207  1.166667    3
# Student        60.000000  2.608696  2.439991  1.166667   23
# Assistant      14.666667  1.466667  0.959198  1.166667   10
# Manager        22.166667  1.847222  1.833965  1.166667   12
# Academia       28.500000  4.071429  7.968170  1.083333    7
# CEO             1.083333  1.083333       NaN  1.083333    1
# Postdoc        16.250000  1.805556  1.388819  1.083333    9
# Designer       11.916667  1.702381  1.492153  1.000000    7
# Intern         22.250000  0.404545  0.251752  0.333333   55

# %%
summaryTable = summaryTable.drop(['Student','Other'])
print summaryTable
# Out:
#                      sum      mean       std    median  len
# JobType
# Founder        30.250000  4.321429  2.349856  4.000000    7
# Consultant     20.500000  2.050000  1.450415  2.125000   10
# Engineer       54.750000  2.737500  3.556178  2.083333   20
# PM              4.833333  1.611111  0.822147  2.000000    3
# Scientist       9.250000  2.312500  1.167410  1.916667    4
# Research      118.416667  2.041667  1.928311  1.416667   58
# Software Eng    7.250000  2.416667  2.994207  1.166667    3
# Assistant      14.666667  1.466667  0.959198  1.166667   10
# Manager        22.166667  1.847222  1.833965  1.166667   12
# Academia       28.500000  4.071429  7.968170  1.083333    7
# CEO             1.083333  1.083333       NaN  1.083333    1
# Postdoc        16.250000  1.805556  1.388819  1.083333    9
# Designer       11.916667  1.702381  1.492153  1.000000    7
# Intern         22.250000  0.404545  0.251752  0.333333   55

# %%
# (*) To communicate with Plotly's server, sign in with credentials file
import plotly.plotly as py
py.sign_in("lchricus", "4urjjs5ptp")

# (*) Useful Python/Plotly tools
import plotly.tools as tls   

# (*) Graph objects to piece together plots
from plotly.graph_objs import *

# %%
# Make list of Box traces

jobTypes = pandas.unique(summaryTable.index.ravel()).tolist()

traces= None
traces = [
    Box(
        y=numpy.array(jobs['Duration_yr'][jobs['JobType']==ii]),
        #name='{}'.format(ii) 
        name = ii
    ) 
    for ii in jobTypes]

# Make Data object made up of 120 Box object 
plotdata = Data(traces)

# Make figure object
fig = Figure(data=plotdata)

# (@) Send to Plotly and show plot in notebook
py.iplot(fig)

# %%
# Make list of Box traces

traces= None
traces = [
    Bar(
        x = pandas.unique(summaryTable.index.ravel()).tolist(),
        y = numpy.array(summaryTable['median']),
    ) 
]

# Make Data object made up of 120 Box object 
plotdata = Data(traces)

# Make figure object
fig = Figure(data=plotdata)

# (@) Send to Plotly and show plot in notebook
py.iplot(fig)

# %%
jobscur = pandas.read_csv('../datacur.csv')
jobscur = jobscur[jobscur.Duration_yr >= 0]

# %%
jobscur.head()
# Out:
#                                   JobTitle            Company StartDate  \
# 0  Research Analyst and Grants Coordinator       TEC Edmonton   2011/10
# 1                                   Editor         MetaboNews    2011/7
# 2                          Product Manager             Google    2014/8
# 3                                  Founder           drone.vc    2014/5
# 4                                   Mentor  Founder Institute    2010/5
#
#    Duration_yr   JobType
# 0     3.126408  Research
# 1     3.378463     Other
# 2     0.290792   Manager
# 3     0.542847   Founder
# 4     4.545586     Other

# %%
jobscurGroups = jobscur.groupby('JobType')
summaryTableCur = jobscurGroups['Duration_yr'].agg([np.sum, np.mean, np.std, np.median, len]).sort('median', ascending=False)
print summaryTableCur
# Out:
#                       sum      mean       std    median  len
# JobType
# CEO             83.411648  9.267961  7.231950  7.877093    9
# Student        392.645557  4.006587  1.732083  4.208600   98
# Academia       162.491571  4.166451  4.953416  2.874354   39
# Research       247.645013  3.301934  4.564955  2.457915   75
# Designer        56.669872  3.148326  3.682420  1.874354   18
# Software Eng    48.877256  2.125098  2.013726  1.871614   23
# Engineer       163.631460  2.682483  3.161715  1.709970   61
# Founder        163.745839  3.148958  3.064053  1.705860   52
# Postdoc         61.719041  1.928720  1.349823  1.583943   32
# PM              35.946965  1.891946  1.734742  1.542847   19
# Consultant     122.209688  2.600206  3.437001  1.457915   47
# Other         1570.937898  2.501493  3.736731  1.457915  628
# Manager        208.896396  2.048004  2.800593  1.416819  102
# Assistant       79.500861  1.622467  1.666810  1.290792   49
# Scientist       80.376957  2.435665  3.444055  1.290792   33
# Intern          25.531289  1.215776  1.193773  0.625039   21

# %%
summaryTableCur = summaryTableCur.drop(['Student','Other'])
print summaryTableCur
# Out:
#                      sum      mean       std    median  len
# JobType
# CEO            83.411648  9.267961  7.231950  7.877093    9
# Academia      162.491571  4.166451  4.953416  2.874354   39
# Research      247.645013  3.301934  4.564955  2.457915   75
# Designer       56.669872  3.148326  3.682420  1.874354   18
# Software Eng   48.877256  2.125098  2.013726  1.871614   23
# Engineer      163.631460  2.682483  3.161715  1.709970   61
# Founder       163.745839  3.148958  3.064053  1.705860   52
# Postdoc        61.719041  1.928720  1.349823  1.583943   32
# PM             35.946965  1.891946  1.734742  1.542847   19
# Consultant    122.209688  2.600206  3.437001  1.457915   47
# Manager       208.896396  2.048004  2.800593  1.416819  102
# Assistant      79.500861  1.622467  1.666810  1.290792   49
# Scientist      80.376957  2.435665  3.444055  1.290792   33
# Intern         25.531289  1.215776  1.193773  0.625039   21

# %%
# comment

jobFunctions = pandas.unique(summaryTable.index.ravel()).tolist()
currentMedians = []
currentNumberPoints = []
currentStds = []
for i in jobFunctions:
    currentMedians.append(summaryTableCur['median'][i])
    currentStds.append(summaryTableCur['std'][i])
    currentNumberPoints.append('# points: ' + str(summaryTableCur['len'][i]))

traces= None
traces = [
    Bar(
        x = jobFunctions,
        y = numpy.array(summaryTable['median']),
        name = 'past jobs',
        text = ["# points: "+str(i) for i in (summaryTable['len'].tolist())],
        error_y=ErrorY(
            type='data',
            array=numpy.array(summaryTable['std']),
            visible=False
        )
    ), 
    Bar(
        x = jobFunctions,
        y = currentMedians,
        name = 'current jobs',
        text = currentNumberPoints,
        error_y=ErrorY(
            type='data',
            array=currentStds,
            visible=False
        )
    )
]

layout = Layout(
    barmode='group',
    font=Font(
        family='Raleway, sans-serif',
        size=18,
    ),
    xaxis=XAxis(
        tickangle=-45
    ),
    yaxis=YAxis(
        title='job duration (years)',
        #zeroline=False,
        gridwidth=2
    ),
)

# Make Data object made up of 120 Box object 
plotdata = Data(traces)

# Make figure object
fig = Figure(data=plotdata, layout=layout)

# (@) Send to Plotly and show plot in notebook
py.iplot(fig)

# %%
jobLocGroups = jobs.groupby('LocationType')
summaryTableLoc = jobLocGroups['Duration_yr'].agg([np.sum, np.mean, np.std, np.median, len]).sort('median', ascending=False)
summaryTableLoc = summaryTableLoc[summaryTableLoc.len > 10]
print summaryTableLoc
# Out:
#                      sum      mean       std    median  len
# LocationType
# MA             98.000000  2.578947  2.321313  1.958333   38
# CA            175.000000  2.108434  2.476849  1.333333   83
# NY             35.916667  2.762821  5.862116  1.000000   13
# Canada         57.750000  1.560811  1.363751  1.000000   37
# Other          24.583333  1.446078  1.582495  0.833333   17
# MO             21.583333  1.541667  1.823619  0.708333   14
# TX             14.833333  0.988889  0.892466  0.583333   15
# Europe         21.833333  1.455556  1.675532  0.500000   15

# %%
# Make list of Box traces

traces= None
traces = [
    Bar(
        x = pandas.unique(summaryTableLoc.index.ravel()).tolist(),
        y = numpy.array(summaryTableLoc['median']),
    ) 
]


layout = Layout(
    barmode='group',
    font=Font(
        family='Raleway, sans-serif',
        size=18,
    ),
    xaxis=XAxis(
        tickangle=-45
    ),
    yaxis=YAxis(
        title='job duration (years)',
        #zeroline=False,
        gridwidth=2
    ),
)

# Make Data object made up of 120 Box object 
plotdata = Data(traces)


# Make figure object
fig = Figure(data=plotdata, layout=layout)

# (@) Send to Plotly and show plot in notebook
py.iplot(fig)

# %%
# Make list of Box traces

jobTypes = pandas.unique(summaryTableLoc.index.ravel()).tolist()

traces= None
traces = [
    Box(
        y=numpy.array(jobs['Duration_yr'][jobs['LocationType']==ii]),
        #name='{}'.format(ii) 
        name = ii
    ) 
    for ii in jobTypes]

# Make Data object made up of 120 Box object 
plotdata = Data(traces)

# Make figure object
fig = Figure(data=plotdata)

# (@) Send to Plotly and show plot in notebook
py.iplot(fig)

# %%
traces= None
traces = [
    Box(
        y=numpy.array(jobs['Duration_yr'][jobs['JobType']=='Student']),
        name = 'graduated',
        #text = '# points: '+str(len(numpy.array(jobs['Duration_yr'][jobs['JobType']=='Student'])))
    ),
    Box(
        y=numpy.array(jobscur['Duration_yr'][jobscur['JobType']=='Student']),
        name = 'in school',
        #text = '# points: '+str(len(numpy.array(jobscur['Duration_yr'][jobscur['JobType']=='Student'])))
    )
]

layout = Layout(
    font=Font(
        family='Raleway, sans-serif',
        size=18,
    ),
    xaxis=XAxis(
        tickangle=-45
    ),
    yaxis=YAxis(
        title='job duration (years)',
        #zeroline=False,
        gridwidth=2
    ),
)


# Make Data object made up of 120 Box object 
plotdata = Data(traces)

# Make figure object
fig = Figure(data=plotdata, layout=layout)

# (@) Send to Plotly and show plot in notebook
py.iplot(fig)

# %%
jobs['startYear'] = jobs['StartDate'].str.split(' ').apply(pandas.Series, 1).stack()[:,1]
jobs['endYear'] = jobs['EndDate'].str.split(' ').apply(pandas.Series, 1).stack()[:,1]
jobs.head()
# Out:
#                      JobTitle               Company       StartDate  \
# 3             Visual Designer      Good World Media       July 2011
# 4        Visual Design Intern                  CIBO    January 2013
# 5   Interactive Design Intern             remind101       July 2012
# 6             Junior Designer  The Shotwell Company  September 2011
# 7  Marketing and Print Intern              Club One  September 2011
#
#           EndDate          Duration                Location  Duration_yr  \
# 3   November 2013  2 years 5 months                New York     2.416667
# 4        May 2013          5 months  San Francisco Bay Area     0.416667
# 5  September 2012          3 months  San Francisco Bay Area     0.250000
# 6       July 2012         11 months  San Francisco Bay Area     0.916667
# 7   December 2011          4 months  San Francisco Bay Area     0.333333
#
#     JobType LocationType startYear endYear
# 3  Designer           NY      2011    2013
# 4    Intern           CA      2013    2013
# 5    Intern           CA      2012    2012
# 6  Designer           CA      2011    2012
# 7    Intern           CA      2011    2011

# %%
trace1 = Scatter(
    x=numpy.array(jobs['startYear']),
    y=numpy.array(jobs['Duration_yr']),
    mode='markers',
    marker=Marker(
        color='rgb(234, 153, 153)',
        size=12,
        line=Line(
            color='white',
            width=0.5
        )
    )
)
trace2 = Scatter(
    x=numpy.array(jobs['endYear']),
    y=numpy.array(jobs['Duration_yr']),
    mode='markers',
    marker=Marker(
        color='rgb(255, 217, 102)',
        size=12,
        line=Line(
            color='white',
            width=0.5
        )
    )
)
plotdata = Data([trace1, trace2])

# Make figure object
fig = Figure(data=plotdata)

# (@) Send to Plotly and show plot in notebook
py.iplot(fig)

# %%
startYearGroups = jobs.groupby('startYear')
summaryTableS = startYearGroups['Duration_yr'].agg([np.sum, np.mean, np.std, np.median, len]).sort('median', ascending=False)
print summaryTableS
# Out:
#                  sum       mean        std     median  len
# startYear
# 1989       22.000000  22.000000        NaN  22.000000    1
# 1997       19.083333   9.541667  10.311974   9.541667    2
# 1998        6.583333   6.583333        NaN   6.583333    1
# 1999        7.666667   2.555556   0.636469   2.416667    3
# 1996        2.250000   2.250000        NaN   2.250000    1
# 2001       23.666667   3.380952   3.042468   2.166667    7
# 2002       20.750000   3.458333   3.993310   1.833333    6
# 2009       55.666667   2.061728   1.523953   1.833333   27
# 2003       19.250000   3.208333   3.574893   1.750000    6
# 2011       54.166667   1.593137   1.013122   1.458333   34
# 2007       49.500000   1.980000   1.913385   1.416667   25
# 2008       69.750000   2.179687   2.026273   1.125000   32
# 2012       45.500000   1.109756   0.804596   0.833333   41
# 2004       33.083333   2.363095   2.734241   0.708333   14
# 2005       23.500000   1.566667   1.979107   0.666667   15
# 2006       25.666667   1.509804   1.622295   0.666667   17
# 2010       32.166667   1.109195   0.913442   0.583333   29
# 2013       15.000000   0.681818   0.455446   0.416667   22
# 2014        3.416667   0.427083   0.215645   0.375000    8
# 2000        0.500000   0.250000   0.000000   0.250000    2

# %%
endYearGroups = jobs.groupby('endYear')
summaryTableE = endYearGroups['Duration_yr'].agg([np.sum, np.mean, np.std, np.median, len]).sort('median', ascending=False)
print summaryTableE
# Out:
#                 sum      mean       std    median  len
# endYear
# 1999       4.500000  2.250000  0.000000  2.250000    2
# 2014     109.166667  2.599206  2.849858  2.083333   42
# 2012      91.583333  2.180556  2.225660  1.541667   42
# 2011      83.166667  2.598958  4.068711  1.500000   32
# 2013      71.250000  1.619318  1.481300  1.166667   44
# 2001       4.916667  1.229167  1.143369  1.125000    4
# 2008      33.083333  1.503788  1.858143  1.083333   22
# 2009      29.333333  1.543860  1.634025  1.083333   19
# 2010      52.250000  1.632812  1.793539  0.916667   32
# 2002       5.250000  1.312500  1.396714  0.875000    4
# 2003       4.083333  0.816667  0.789251  0.666667    5
# 2006      13.833333  0.813725  0.680539  0.666667   17
# 2004       8.750000  1.093750  2.218446  0.333333    8
# 2005       6.333333  0.791667  0.899735  0.333333    8
# 2007      12.166667  1.106061  1.743675  0.333333   11
# 2000       0.500000  0.250000  0.000000  0.250000    2

# %%
# comment

jobFunctions = pandas.unique(summaryTable.index.ravel()).tolist()
currentMedians = []
currentNumberPoints = []
currentStds = []
for i in jobFunctions:
    currentMedians.append(summaryTableCur['median'][i])
    currentStds.append(summaryTableCur['std'][i])
    currentNumberPoints.append('# points: ' + str(summaryTableCur['len'][i]))

traces= None
traces = [
    Bar(
        x = pandas.unique(summaryTableS.index.ravel()).tolist(),
        y = numpy.array(summaryTableS['median']),
        name = 'start year',
        text = ["# points: "+str(i) for i in (summaryTableS['len'].tolist())]
    ), 
    Bar(
        x = pandas.unique(summaryTableE.index.ravel()).tolist(),
        y = numpy.array(summaryTableE['median']),
        name = 'end year',
        text = currentNumberPoints
    )
]

layout = Layout(
    barmode='group',
    font=Font(
        family='Raleway, sans-serif',
        size=18,
    ),
    xaxis=XAxis(
        tickangle=-45
    ),
    yaxis=YAxis(
        title='job duration (years)',
        #zeroline=False,
        gridwidth=2
    ),
)

# Make Data object made up of 120 Box object 
plotdata = Data(traces)

# Make figure object
fig = Figure(data=plotdata, layout=layout)

# (@) Send to Plotly and show plot in notebook
py.iplot(fig)

# %%
trace1 = Scatter(
    x = pandas.unique(summaryTableS.index.ravel()).tolist(),
    y = numpy.array(summaryTableS['median']),
    mode='markers',
    marker=Marker(
        color='rgb(234, 153, 153)',
        size =  numpy.array(summaryTableS['len']),
        line=Line(
            color='white',
            width=0.5
        )
    )
)
trace2 = Scatter(
    x = pandas.unique(summaryTableE.index.ravel()).tolist(),
    y = numpy.array(summaryTableE['median']),
    size =  numpy.array(summaryTableE['len']),
    mode='markers',
    marker=Marker(
        color='rgb(255, 217, 102)',
        size =  numpy.array(summaryTableE['len']),
        line=Line(
            color='white',
            width=0.5
        )
    )
)
plotdata = Data([trace1, trace2])

# Make figure object
fig = Figure(data=plotdata)

# (@) Send to Plotly and show plot in notebook
py.iplot(fig)
# Out:
# ---------------------------------------------------------------------------
# PlotlyDictKeyError                        Traceback (most recent call last)
# <ipython-input-163-17cd2ef4de4a> in <module>()
#      22         line=Line(
#      23             color='white',
# ---> 24             width=0.5
#      25         )
#      26     )
#
# /Users/Lauren/anaconda/lib/python2.7/site-packages/plotly/graph_objs/graph_objs.pyc in __init__(self, *args, **kwargs)
#     748     """
#     749     def __init__(self, *args, **kwargs):
# --> 750         super(PlotlyTrace, self).__init__(*args, **kwargs)
#     751         if self.__class__.__name__ == 'PlotlyTrace':
#     752             warnings.warn("\nThe PlotlyTrace class is a base class of "
#
# /Users/Lauren/anaconda/lib/python2.7/site-packages/plotly/graph_objs/graph_objs.pyc in __init__(self, *args, **kwargs)
#     310             if (class_name != 'PlotlyTrace') and (class_name != 'Trace'):
#     311                 self['type'] = NAME_TO_KEY[class_name]
# --> 312         self.validate()
#     313         if self.__class__.__name__ == 'PlotlyDict':
#     314             warnings.warn("\nThe PlotlyDict class is a base class of "
#
# /Users/Lauren/anaconda/lib/python2.7/site-packages/plotly/graph_objs/graph_objs.pyc in validate(self, caller)
#     598                     raise exceptions.PlotlyDictKeyError(obj=self,
#     599                                                         key=key,
# --> 600                                                         notes=notes)
#     601
#     602     def to_string(self, level=0, indent=4, eol='\n',
#
# PlotlyDictKeyError: Invalid key, 'size', for class, 'Scatter'.
#
# Run 'help(plotly.graph_objs.Scatter)' for more information.
#
# Path To Error:
# ['size']
#
# Additional Notes:
# That key is valid only in these objects:
#
# 	XBins('size'="number: x > 0")
# 	YBins('size'="number: x > 0")
# 	Marker('size'="number: x > 0, or list of these numbers")
# 	Contours('size'="number: x > 0")
# 	Font('size'="number: x > 0")
